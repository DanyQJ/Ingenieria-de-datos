# %% [markdown]
# ## Selecting DataFrame Data

# %%
import pandas as pd
file_path = '../../data/USCG.Search.Rescue.Stats.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#       Fiscal Year  Cases  Responses  Sorties  Lives Saved  \
# 1964          NaN  41525        NaN     2932          NaN
# 1965          NaN  38586        NaN     1984          NaN
# 1966          NaN  43366        NaN     2629          NaN
# 1967          NaN  42225        NaN     3028          NaN
# 1968          NaN  46922        NaN     2434          NaN
#
#       Lives Lost After CG Notification  Lives Lost Before CG Notification  \
# 1964                               NaN                                NaN
# 1965                               NaN                                NaN
# 1966                               NaN                                NaN
# 1967                               NaN                                NaN
# 1968                               NaN                                NaN
#
#       Total  Lives Unaccounted For
# 1964    NaN                     NaN
# 1965    NaN                     NaN
# 1966    NaN                     NaN
# ...

# %% [markdown]
# ### Boolean Mask

# %%
# Creamos una máscara de booleanos con el mismo tamaño que el DataFrame, inicialmente con todos los valores en False
mask = [False for _ in range(len(df))] 
# Establecemos los valores de la máscara a True para las filas que queremos seleccionar (en este caso, las filas 3 a 6)
mask[3:7] = [True] * 4 
mask
# Out:
# [False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
df[mask]
# Out:
#       Fiscal Year  Cases  Responses  Sorties  Lives Saved  \
# 1967          NaN  42225        NaN     3028          NaN
# 1968          NaN  46922        NaN     2434          NaN
# 1969          NaN  48720        NaN     2050          NaN
# 1970      44975.0  52183    62286.0     4135       1783.0
#
#       Lives Lost After CG Notification  Lives Lost Before CG Notification  \
# 1967                               NaN                                NaN
# 1968                               NaN                                NaN
# 1969                               NaN                                NaN
# 1970                               NaN                             1783.0
#
#       Total  Lives Unaccounted For
# 1967    NaN                     NaN
# 1968    NaN                     NaN
# 1969    NaN                     NaN
# 1970    NaN                     NaN

# %%
# Otra forma de seleccionar filas usando la máscara es con loc, que es un indexador basado en etiquetas. En este caso, como la máscara es un array de booleanos, loc seleccionará las filas correspondientes a los valores True en la máscara.
df.loc[mask]
# Out:
#       Fiscal Year  Cases  Responses  Sorties  Lives Saved  \
# 1967          NaN  42225        NaN     3028          NaN
# 1968          NaN  46922        NaN     2434          NaN
# 1969          NaN  48720        NaN     2050          NaN
# 1970      44975.0  52183    62286.0     4135       1783.0
#
#       Lives Lost After CG Notification  Lives Lost Before CG Notification  \
# 1967                               NaN                                NaN
# 1968                               NaN                                NaN
# 1969                               NaN                                NaN
# 1970                               NaN                             1783.0
#
#       Total  Lives Unaccounted For
# 1967    NaN                     NaN
# 1968    NaN                     NaN
# 1969    NaN                     NaN
# 1970    NaN                     NaN

# %% [markdown]
# ### Creating mask using comparison operators

# %%
mask = df.loc[:, 'Lives Lost After CG Notification'] < df.loc[:, 'Lives Lost Before CG Notification']
mask
# Out:
# 1964    False
# 1965    False
# 1966    False
# 1967    False
# 1968    False
# 1969    False
# 1970    False
# 1971    False
# 1972    False
# 1973    False
# 1974    False
# 1975    False
# 1976    False
# 1977    False
# 1978    False
# 1979     True
# 1980     True
# 1981     True
# 1982     True
# 1983     True
# 1984     True
# 1985     True
# 1986     True
# 1987     True
# 1988     True
# 1989     True
# 1990     True
# 1991     True
# 1992     True
# 1993     True
# 1994     True
# 1995     True
# 1996     True
# 1997     True
# 1998     True
# 1999     True
# 2000     True
# 2001     True
# 2002     True
# 2003     True
# 2004     True
# 2005     True
# 2006     True
# 2007     True
# 2008     True
# 2009     True
# 2010     True
# 2011     True
# 2012     True
# 2013     True
# 2014     True
# 2015     True
# dtype: bool

# %%
df[mask]
# Out:
#       Fiscal Year  Cases  Responses  Sorties  Lives Saved  \
# 1979      72517.0  79858    92117.0     5747        949.0
# 1980      73345.0  81476    93726.0     6868       1235.0
# 1981      71781.0  78951    91432.0     6339       1080.0
# 1982      68552.0  75717    87715.0     5675       1359.0
# 1983      63980.0  72585    85796.0     5946       1121.0
# 1984      57431.0  66073    80698.0     5645       1148.0
# 1985      60775.0  70237    88449.0     6497       1076.0
# 1986      51765.0  68805    89318.0     4307        475.0
# 1987      55998.0  66656    87211.0     5785       1015.0
# 1988      54199.0  63446    83616.0     4307        583.0
# 1989      52776.0  64027    81862.0     3981        461.0
# 1990      53097.0  64971    84033.0     4407        463.0
# 1991      52782.0  66409    84872.0     5465        368.0
# 1992      53294.0  69856    88388.0     5543        399.0
# 1993      53026.0  69784    88147.0     5826        415.0
# ...

# %% [markdown]
# ### Pandas Boolean operators

# %% [markdown]
# 1. And: &
# 2. Or: |
# 3. Not: ~
